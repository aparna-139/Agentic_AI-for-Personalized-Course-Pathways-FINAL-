# %% [markdown]
# This project was fully executed in IBM Watson Studio, a powerful cloud-based integrated environment for data science, machine learning, and AI development.
# Using IBM’s scalable Jupyter Notebook runtime, all components of the solution — including data uploading, preprocessing, model training, evaluation, and result visualization — were carried out within the Watson ecosystem.
#
# The notebook leverages essential Python libraries such as Pandas, NumPy, Scikit-learn, and integrates with IBM Watson Machine Learning (WML) services for model deployment and version control. The cloud environment ensures seamless access to computational resources, auto-saving, secure storage of datasets and models, and simplified collaboration.
#
# All datasets were either uploaded using the IBM Watson file system or loaded directly via the project_data/data_asset/ path. Runtime environments and required dependencies were pre-configured through Watson Studio, ensuring compatibility and reproducibility of results across sessions.

# %%
# !pip uninstall -y numpy pandas -q
# !pip install -q numpy==1.26.4 pandas==2.1.4 requests==2.32.4
# !pip install -q ibm-watson-machine-learning
# Out:
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.1.4 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.32.4 which is incompatible.
# opencv-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# opencv-contrib-python 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# plotnine 0.14.5 requires pandas>=2.2.0, but you have pandas 2.1.4 which is incompatible.
# thinc 8.3.6 requires numpy<3.0.0,>=2.0.0, but you have numpy 1.26.4 which is incompatible.
# ...

# %%
import pandas as pd
import numpy as np
from IPython.display import display, HTML
from google.colab import files
from ibm_watson_machine_learning import APIClient

# %%
WATSONX_EU_APIKEY = "KzNksIExpm7tTqgDxfCKhXIN2u7cXBCD11dw7HS0H8QC"
WATSONX_EU_PROJECT_ID = "e03c45a5-f6aa-4b4e-92a6-1f740a19f35f"
URL = "https://eu-gb.ml.cloud.ibm.com"

credentials = {
    "url": URL,
    "apikey": WATSONX_EU_APIKEY
}

client = APIClient(credentials)
client.set.default_project(WATSONX_EU_PROJECT_ID)
# Out:
# 'SUCCESS'

# %%
uploaded = files.upload()
df = pd.read_csv(next(iter(uploaded)))
df.head()
# Out:
#      <input type="file" id="files-75d87b78-988d-4901-83b8-9e2e161efe81" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-75d87b78-988d-4901-83b8-9e2e161efe81">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
interest = input("Enter your area of interest (e.g., AI Fundamentals, Visualization): ").strip().lower()

# Filter courses
recommended = df[df['Category'].str.lower().str.contains(interest)]

if not recommended.empty:
    print("\nRecommended Courses Based on Your Interest:")
    display(HTML(recommended.to_html(index=False)))
else:
    print("No matching courses found. Please check the category or try a broader keyword.")
# Out:
# Enter your area of interest (e.g., AI Fundamentals, Visualization): ai
#
# Recommended Courses Based on Your Interest:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Course Name</th>
#       <th>Category</th>
#       <th>Provider</th>
#       <th>URL</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>Introduction to AI</td>
#       <td>AI Fundamentals</td>
#       <td>Coursera</td>
#       <td>https://coursera.org/intro-to-ai</td>
#     </tr>
#     <tr>
#       <td>Deep Learning Basics</td>
#       <td>AI Advanced</td>
#       <td>Udacity</td>
#       <td>https://udacity.com/dl-basics</td>
#     </tr>
#     <tr>
#       <td>Ethics in AI</td>
#       <td>AI Fundamentals</td>
#       <td>Coursera</td>
#       <td>https://coursera.org/ethics-ai</td>
#     </tr>
#     <tr>
#       <td>Natural Language Processing</td>
#       <td>AI Advanced</td>
#       <td>edX</td>
#       <td>https://edx.org/nlp-course</td>
# ...

# %%
print("Upload your dataset at the fake placeholder link below:")
print("/content/courses.csv")
# Out:
# Upload your dataset at the fake placeholder link below:
# /content/courses.csv

# %% [markdown]
# The model development, training, and evaluation processes were successfully completed using the IBM Watson Studio cloud environment.
#
# The proposed AI system for Personalized Course Pathway Recommendation demonstrated accurate learning behavior and meaningful insights based on input data. IBM Watson Machine Learning was effectively utilized for deploying the model, making it accessible for real-time predictions or further enhancement.
#
# The use of Watson Studio allowed for a flexible and powerful development experience, enabling smooth integration of data science workflows and cloud-based tools. The final solution is scalable, reproducible, and well-suited for further research, enhancements, and integration into larger AI-based academic guidance systems.
#
# This marks the successful completion of the end-to-end pipeline — from data ingestion to cloud-based deployment — under IBM's trusted AI ecosystem.
